# %% [markdown]
# # CNN_eda

# %% [markdown]
# ## Mount Google Drive

# %%
# Colab 사용시
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Install

# %%
# !java -version
# %pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: konlpy in /usr/local/lib/python3.7/dist-packages (0.6.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.9.1)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (4.1.1)

# %% [markdown]
# ## Import Library

# %%
# data
import pandas as pd
import pickle

# preprocessing
from konlpy.tag import Komoran
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# model
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Embedding, Conv1D, GlobalMaxPooling1D, Dropout
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# evaluation
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# visualization
import matplotlib.pyplot as plt
import seaborn as sn

# env
import os
from tqdm import tqdm
# import hangul_font

# %% [markdown]
# ## GPU Check

# %%
if tf.test.gpu_device_name():
    print('GPU found')
else:
    print('No GPU found')
# Out:
# No GPU found

# %% [markdown]
# ## Hyper parameters

# %%
# Colab
DATA_DIR = '/content/drive/MyDrive/miso/new_intelli/data/'
SAVE_DIR = '/content/drive/MyDrive/miso/new_intelli/model/CNN_eda/'
LOAD_DIR = '/content/drive/MyDrive/miso/new_intelli/model/CNN_eda/'

# Local
# DATA_DIR = '/Users/inseoklee/Desktop/miso/intelli/data/'
# SAVE_DIR = '/Users/inseoklee/Desktop/miso/intelli/model/CNN_eda/'
# LOAD_DIR = '/Users/inseoklee/Desktop/miso/intelli/model/CNN_eda/'

# Model
# MAX_LEN -> 패딩 단계에서 설정
OUTPUT_DIM = 128 # Embedding layer
FILTERS = 64 # Conv1D layer
KERNEL_SIZE = 3 # Conv1D layer
UNITS = 128 # Dense layer
RATE = 0.2 # Dropout layer

# Evaluation
EPOCHS = 10
VERBOSE = 1
BATCH_SIZE = 128
PATIENCE = 3
VALIDATION_SPLIT = 0.2
OUTPUT = 7

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv(DATA_DIR + 'eda_intelli.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641183 entries, 0 to 641182
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   답변      641183 non-null  object
#  1   지능      641183 non-null  object
# dtypes: object(2)
# memory usage: 9.8+ MB

# %% [markdown]
# ## Train Test Split

# %%
X = df.답변
y = df.지능

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=True, random_state=34, stratify=y
)

# %%
print('X_train shape: ', X_train.shape)
print('y_train shape: ', y_train.shape)
print('\nX_test shape: ', X_test.shape)
print('y_test shape: ', y_test.shape)
# Out:
# X_train shape:  (512946,)
# y_train shape:  (512946,)
#
# X_test shape:  (128237,)
# y_test shape:  (128237,)

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Train Tokenization

# %%
komoran = Komoran()

# 불용어(Stop Words) 제거
stop_pos_tags = ['IC', 'JKS', 'JKC', 'JKG', 'JKO', 'JKB', 'JKV', 'JKQ', 'JX',
                   'EF', 'ETN', 'ETM', 'XSA', 'SF', 'SP', 'SS', 'SE', 'SO', 'SL', 'SH',
                   'SW', 'NF', 'NV', 'SN', 'NA']

# 어간 원형 복원(Lemmatization)
# 동사와 형용사의 경우에는 어간(Stem)에 '다'를 붙여서 기본형으로 복원
def tokenize(corpus, stop_pos_tags):
    result = []
    pairs = komoran.pos(corpus)
    for pair in pairs:
        morph, pos = pair
        if pos not in stop_pos_tags:
            if pos in ['VV', 'VA', 'VX', 'VCP', 'VCN']:
                morph = morph + '다'
            result.append(morph)
    return result

# %%
# 토큰을 만들고 리스트에 저장
clean_train_text = []
for sample in tqdm(X_train):
    clean_train_text.append(tokenize(sample, stop_pos_tags))
# Out:
# 100%|██████████| 512946/512946 [03:45<00:00, 2274.65it/s]

# %%
clean_train_text[:3]
# Out:
# [['조', '소설집', '이야기', '상상', '하', '게', '조금', '행복', '하', '아'],
#  ['태평소', '연주', '하', '면서', '노래', '부르다', '게', '기쁘다', '어'],
#  ['구경', '하', '게', '잔디', '을', '좋다', '아']]

# %% [markdown]
# ### Test Tokenization

# %%
# 토큰을 만들고 리스트에 저장
clean_test_text = []
for sample in tqdm(X_test):
    clean_test_text.append(tokenize(sample, stop_pos_tags))
# Out:
# 100%|██████████| 128237/128237 [01:02<00:00, 2057.72it/s]

# %% [markdown]
# ### Vectorization

# %%
tokenizer_name = 'tokenizer.pickle'
save_path = os.path.join(SAVE_DIR, tokenizer_name)

tokenizer = Tokenizer(oov_token=True)

tokenizer.fit_on_texts(clean_train_text)
train_sequences = tokenizer.texts_to_sequences(clean_train_text)
test_sequences = tokenizer.texts_to_sequences(clean_test_text)

with open(save_path, 'wb') as f:
    pickle.dump(tokenizer, f, protocol=pickle.HIGHEST_PROTOCOL)

print(train_sequences[:3])
# Out:
# [[66, 211, 39, 93, 3, 2, 27, 13, 3, 5], [456, 40, 3, 17, 101, 110, 2, 16, 4], [48, 3, 2, 1136, 36, 8, 5]]

# %% [markdown]
# 단어의 수 / 사전의 크기

# %%
VOCAB_SIZE = len(tokenizer.word_index) + 1
print(VOCAB_SIZE)
# Out:
# 1927

# %%
token_dic = tokenizer.word_counts
d2 = sorted(token_dic.items(), key=lambda x: x[1], reverse=True)
print(d2)
# Out:
# [('게', 521465), ('하', 327509), ('어', 212861), ('아', 199815), ('잘', 106862), ('나', 102851), ('좋다', 81251), ('재밌다', 77491), ('되다', 77360), ('하다', 76657), ('거', 75456), ('행복', 74768), ('즐겁다', 73182), ('매우', 72570), ('기쁘다', 70235), ('면서', 64629), ('고', 63621), ('있다', 58994), ('신', 56209), ('아요', 49490), ('어요', 49131), ('친구', 46353), ('읽다', 45960), ('보다', 43527), ('그림', 41600), ('조금', 40317), ('진짜', 40292), ('엄청', 32912), ('좀', 31520), ('너무', 31452), ('꽤', 31446), ('항상', 31321), ('정말', 31302), ('주다', 30320), ('을', 29589), ('그리다', 27370), ('만들다', 26091), ('이야기', 25582), ('연주', 25484), ('듣다', 24859), ('수', 24671), ('소리', 23799), ('놓다', 23500), ('지다', 23408), ('는지', 22999), ('꿈', 22412), ('구경', 22046), ('어서', 20624), ('관찰', 19802), ('때', 19759), ('배우다', 19575), ('속', 19208), ('엄마', 18683), ('지', 17997), ('신나다', 17523), ('뛰다', 17044), ('요', 16683), ('이다', 16663), ('들', 16373), ('아빠', 15563), ('그릴', 15498), ('뭔', 15328), ('과', 14818), ('섞다', 13721), ('조', 13498), ('쓰다', 12754), ('시간', 11978), ('이랑', 11856), ('모양', 11498), ('어떤', 11025), ('색', 11009), ('어떻다', 10696), ('나오다', 10670), ('색깔', 10612), ('ㄴ지', 10254), ('주인공', 10083), ('예쁘다', 10018), ('맞추다', 10015), ('무슨', 9673), ('여러', 9623), ('색칠', 9267), ('만나다', 9125), ('알다', 9056), ('나다', 9029), ('아서', 8980), ('같이', 8686), ('내다', 8558), ('가지다', 8344), ('숫자', 8281), ('말', 8247), ('걸다', 8108), ('상상', 8061), ('것', 8022), ('놀다', 7748), ('놀이', 7743), ('으면', 7402), ('많이', 7260), ('전', 7079), ('물감', 6980), ('노래', 6960), ('잠들다', 6948), ('그', 6837), ('나누다', 6746), ('소', 6534), ('역할', 6499), ('극', 6499), ('십', 6279), ('똑똑', 6275), ('부르다', 6223), ('이', 6162), ('다른', 6031), ('선생님', 5952), ('먹이', 5926), ('치다', 5901), ('시', 5872), ('선', 5823), ('와', 5797), ('기르다', 5598), ('맞히다', 5591), ('동물', 5515), ('공부', 5276), ('르', 5223), ('지내다', 5154), ('흉내', 4952), ('짜다', 4914), ('뭐', 4822), ('곱하다', 4679), ('대하다', 4664), ('일', 4646), ('음악', 4569), ('점', 4566), ('빼다', 4564), ('구하다', 4441), ('구분', 4427), ('입', 4409), ('타다', 4315), ('악기', 4297), ('세다', 4130), ('단', 4092), ('내', 4090), ('종이', 4086), ('사람', 4079), ('다고', 4049), ('받다', 3974), ('동화', 3915), ('좋아하다', 3828), ('더하다', 3818), ('초록색', 3786), ('사랑', 3730), ('집', 3715), ('빨간색', 3706), ('블록', 3676), ('으면서', 3669), ('보라색', 3658), ('파란색', 3652), ('남색', 3645), ('이십', 3618), ('주황색', 3580), ('노란색', 3576), ('사', 3550), ('은지', 3422), ('단어', 3419), ('얼마나', 3407), ('도형', 3389), ('동생', 3326), ('싶다', 3255), ('칭찬', 3246), ('들다', 3012), ('동화책', 3011), ('금', 3009), ('었', 2999), ('미', 2925), ('물건', 2924), ('책', 2899), ('노력', 2878), ('오늘', 2870), ('공', 2858), ('꽃', 2857), ('따르다', 2837), ('안', 2816), ('단편', 2804), ('면', 2800), ('그림책', 2772), ('삽화', 2753), ('비교', 2726), ('소설', 2715), ('가지', 2691), ('만', 2678), ('놀이터', 2660), ('찾다', 2591), ('명작', 2585), ('권', 2574), ('산문집', 2571), ('수필집', 2569), ('전집', 2568), ('동양화', 2567), ('중단편', 2566), ('단편집', 2564), ('행동', 2558), ('서다', 2558), ('소설화', 2558), ('소설책', 2552), ('그리고', 2547), ('모음집', 2541), ('작품집', 2531), ('도와주다', 2530), ('논픽션', 2523), ('시집', 2521), ('동화집', 2520), ('소설집', 2517), ('천자문', 2507), ('뒤', 2505), ('계산', 2498), ('외전', 2490), ('몇', 2442), ('게임', 2390), ('이름', 2388), ('며', 2309), ('갖다', 2251), ('림', 2248), ('알아맞히다', 2241), ('색연필', 2208), ('치', 2204), ('기뻐하다', 2199), ('종이접기', 2197), ('장난감', 2177), ('사이', 2177), ('거나', 2167), ('삼', 2161), ('세', 2138), ('연필', 2134), ('크다', 2131), ('쌓다', 2117), ('앞', 2115), ('크레파스', 2083), ('요일', 2075), ('세모', 2061), ('동그라미', 2055), ('심부름', 2054), ('네모', 2054), ('날짜', 2051), ('든', 2048), ('아야', 2010), ('카드', 2003), ('유치원', 2001), ('가족', 1994), ('산수', 1984), ('식물', 1970), ('친하다', 1961), ('자전거', 1952), ('퍼즐', 1943), ('려고', 1938), ('우리', 1929), ('형', 1891), ('가', 1885), ('공책', 1869), ('북', 1850), ('같다', 1848), ('아프다', 1846), ('손', 1831), ('재미있다', 1797), ('구', 1741), ('비슷', 1724), ('위', 1711), ('얘기', 1709), ('별', 1689), ('길다', 1687), ('어느', 1682), ('이용', 1647), ('무겁다', 1625), ('어디', 1595), ('오빠', 1594), ('언니', 1593), ('시계', 1592), ('쓰기', 1582), ('사이좋다', 1550), ('추다', 1537), ('양보', 1534), ('인지', 1534), ...

# %% [markdown]
# ### Padding

# %%
print('텍스트의 최대 길이 :',max(len(text) for text in train_sequences))
print('텍스트의 평균 길이 :',sum(map(len, train_sequences))/len(train_sequences))
plt.hist([len(text) for text in train_sequences], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 텍스트의 최대 길이 : 49
# 텍스트의 평균 길이 : 9.58612407543874

# %%
trunc_type = 'post'
padding_type = 'post'
MAX_LEN = int(max(len(text) for text in train_sequences) * 95 / 100)

X_train = pad_sequences(train_sequences, maxlen=MAX_LEN, padding=padding_type, truncating=trunc_type)
X_test= pad_sequences(test_sequences, maxlen=MAX_LEN, padding=padding_type, truncating=trunc_type)

# %% [markdown]
# ## Labeling

# %%
y_train.unique()
# Out:
# array(['언어', '음악', '자연', '관계', '미술', '신체', '수리'], dtype=object)

# %%
intelli_dic = {
    '관계': 0, '미술': 1, '수리': 2, '신체': 3, '언어': 4, '음악': 5, '자연': 6
}

# %%
y_train = y_train.replace(intelli_dic)
y_test = y_test.replace(intelli_dic)
y_train.unique()
# Out:
# array([4, 5, 6, 0, 1, 3, 2])

# %% [markdown]
# ## Model definition

# %%
model = Sequential()
model.add(Embedding(input_dim=VOCAB_SIZE, output_dim=OUTPUT_DIM, mask_zero=True))
model.add(Dropout(RATE))
model.add(Conv1D(FILTERS, KERNEL_SIZE, padding='valid', activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(UNITS, activation='relu'))
model.add(Dropout(rate=RATE))
model.add(Dense(OUTPUT, activation='softmax'))

es = EarlyStopping(monitor='val_loss', mode='min', verbose=VERBOSE, patience=PATIENCE, restore_best_weights=True)
mcp = ModelCheckpoint(SAVE_DIR + 'best-model.h5', monitor='val_accuracy', mode='max', verbose=VERBOSE, save_best_only=True)

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ## Train

# %%
history = model.fit(
    X_train, y_train, epochs=EPOCHS, callbacks=[es, mcp], batch_size=BATCH_SIZE, validation_split=VALIDATION_SPLIT
)
# Out:
# Epoch 1/10
# 3205/3206 [============================>.] - ETA: 0s - loss: 0.0598 - accuracy: 0.9817
# Epoch 1: val_accuracy improved from -inf to 0.99639, saving model to /content/drive/MyDrive/miso/new_intelli/model/CNN_eda/best-model.h5
# 3206/3206 [==============================] - 110s 34ms/step - loss: 0.0598 - accuracy: 0.9817 - val_loss: 0.0111 - val_accuracy: 0.9964
# Epoch 2/10
# 3206/3206 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 0.9966
# Epoch 2: val_accuracy improved from 0.99639 to 0.99682, saving model to /content/drive/MyDrive/miso/new_intelli/model/CNN_eda/best-model.h5
# 3206/3206 [==============================] - 108s 34ms/step - loss: 0.0099 - accuracy: 0.9966 - val_loss: 0.0094 - val_accuracy: 0.9968
# Epoch 3/10
# 3206/3206 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9970
# Epoch 3: val_accuracy improved from 0.99682 to 0.99689, saving model to /content/drive/MyDrive/miso/new_intelli/model/CNN_eda/best-model.h5
# 3206/3206 [==============================] - 108s 34ms/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 0.0087 - val_accuracy: 0.9969
# Epoch 4/10
# 3205/3206 [============================>.] - ETA: 0s - loss: 0.0073 - accuracy: 0.9973
# Epoch 4: val_accuracy improved from 0.99689 to 0.99711, saving model to /content/drive/MyDrive/miso/new_intelli/model/CNN_eda/best-model.h5
# 3206/3206 [==============================] - 107s 33ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.0084 - val_accuracy: 0.9971
# Epoch 5/10
# 3205/3206 [============================>.] - ETA: 0s - loss: 0.0069 - accuracy: 0.9974
# Epoch 5: val_accuracy improved from 0.99711 to 0.99719, saving model to /content/drive/MyDrive/miso/new_intelli/model/CNN_eda/best-model.h5
# 3206/3206 [==============================] - 107s 33ms/step - loss: 0.0069 - accuracy: 0.9974 - val_loss: 0.0083 - val_accuracy: 0.9972
# Epoch 6/10
# 3205/3206 [============================>.] - ETA: 0s - loss: 0.0065 - accuracy: 0.9976
# Epoch 6: val_accuracy improved from 0.99719 to 0.99728, saving model to /content/drive/MyDrive/miso/new_intelli/model/CNN_eda/best-model.h5
# 3206/3206 [==============================] - 108s 34ms/step - loss: 0.0065 - accuracy: 0.9976 - val_loss: 0.0077 - val_accuracy: 0.9973
# Epoch 7/10
# 3205/3206 [============================>.] - ETA: 0s - loss: 0.0063 - accuracy: 0.9976
# Epoch 7: val_accuracy did not improve from 0.99728
# 3206/3206 [==============================] - 108s 34ms/step - loss: 0.0063 - accuracy: 0.9976 - val_loss: 0.0090 - val_accuracy: 0.9972
# Epoch 8/10
# 3206/3206 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9977
# Epoch 8: val_accuracy did not improve from 0.99728
# 3206/3206 [==============================] - 108s 34ms/step - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.0081 - val_accuracy: 0.9971
# Epoch 9/10
# 3206/3206 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9977Restoring model weights from the end of the best epoch: 6.
#
# Epoch 9: val_accuracy improved from 0.99728 to 0.99731, saving model to /content/drive/MyDrive/miso/new_intelli/model/CNN_eda/best-model.h5
# 3206/3206 [==============================] - 108s 34ms/step - loss: 0.0059 - accuracy: 0.9977 - val_loss: 0.0088 - val_accuracy: 0.9973
# Epoch 9: early stopping

# %% [markdown]
# ## Test

# %%
loaded_model = load_model(LOAD_DIR + 'best-model.h5')
loss, acc = loaded_model.evaluate(X_test, y_test)
print('Test loss: ', loss)
print('Test accuracy: ', acc)
# Out:
# 4008/4008 [==============================] - 12s 3ms/step - loss: 0.0073 - accuracy: 0.9975
# Test loss:  0.007290578912943602
# Test accuracy:  0.9975045919418335

# %% [markdown]
# ## Visualization

# %%
fig, loss_ax = plt.subplots()
acc_ax = loss_ax.twinx()

loss_ax.plot(history.history['loss'], 'y', label='train loss')
loss_ax.plot(history.history['val_loss'], 'r', label='val loss')

acc_ax.plot(history.history['accuracy'], 'b', label='train acc')
acc_ax.plot(history.history['val_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %% [markdown]
# ## Save model

# %%
model_name = 'trained-model.h5'

# Save model and weights
model_path = os.path.join(SAVE_DIR, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)
# Out:
# Saved trained model at /content/drive/MyDrive/miso/new_intelli/model/CNN_eda/trained-model.h5

# %% [markdown]
# ## Evaluation

# %%
y_pred = loaded_model.predict(X_test)
y_pred = y_pred.argmax(axis=-1)
print(y_pred)
# Out:
# [4 1 6 ... 1 6 5]

# %% [markdown]
# ### Confusion matrix

# %%
# constant for classes
classes = ('관계', '미술', '수리', '신체', '언어', '음악', '자연')

# Build confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)
print(cf_matrix)
df_cm = pd.DataFrame(cf_matrix/cf_matrix.sum(axis=1).reshape(7, 1), index = [i for i in classes],
                     columns = [i for i in classes])
plt.figure(figsize = (12,10))
sn.heatmap(df_cm, annot=True, cmap='Blues')
plt.savefig(SAVE_DIR + '/output.png')
# Out:
# [[19002     1     6    29     3     5     0]
#  [    3 18811    17    10     5     0     2]
#  [    2     2 18878    75     5     3     2]
#  [    6     2    20 16573     4     4     2]
#  [    2     0    10    35 23960     1     2]
#  [    1     3     8    12     1 15105     1]
#  [    3     0    10    18     1     4 15588]]
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48120 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49696 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49888 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52404 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50616 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50612 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50501 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44288 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48120 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49696 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49888 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 52404 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50616 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50612 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51020 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50501 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### precision, recall, f1 score

# %%
acc_score = accuracy_score(y_test, y_pred)
prec_score = precision_score(y_test, y_pred, average='macro')
re_score = recall_score(y_test, y_pred, average='macro')
f1_score = f1_score(y_test, y_pred, average='macro')
print("accuracy_score: ", acc_score)
print("precision_score: ", prec_score)
print("recall_score: ", re_score)
print("f1_score: ", f1_score)
# Out:
# accuracy_score:  0.9975046203513807
# precision_score:  0.9973936114115701
# recall_score:  0.997520255681966
# f1_score:  0.9974540312758418

# %% [markdown]
# ## Load Model

# %%
def load_tokenizer(path):
    with open(path, 'rb') as f:
        tokenizer = pickle.load(f)
    return tokenizer

model_name = 'trained-model.h5'
tokenizer_name = 'tokenizer.pickle'
model_path = os.path.join(LOAD_DIR, model_name)
tokenizer_path = os.path.join(LOAD_DIR, tokenizer_name)

model = load_model(model_path)
tokenizer = load_tokenizer(tokenizer_path)

# %%
def getResult(predict) :
    highest = 0
    highestIdx = 0
    for x in range (0,len(predict)) :
        if(predict[x] > highest) :
            highestIdx = x
            highest =predict[x]
    return highestIdx

def predict_label(text, model):
    tokens = []
    tokenized = tokenize(text, stop_pos_tags)
    if(len(tokenized) == 0) :
        return "너무 짧아"
    tokens.append(tokenized)
    tokens = tokenizer.texts_to_sequences(tokens)
    x_test = pad_sequences(tokens, maxlen=MAX_LEN)
    predict = model.predict(x_test)
    # print(predict)
    result = getResult(predict[0])
    # '관계', '미술', '수리', '신체', '언어', '음악', '자연'
    if result == 0 :
        return '관계'
    elif result == 1 :
        return '미술'
    elif result == 2 :
        return '수리'
    elif result == 3 :
        return '신체'
    elif result == 4 :
        return '언어'
    elif result == 5 :
        return '음악'
    elif result == 6 :
        return '자연'

# %% [markdown]
# ## 3가지 레이블에 대한 예측

# %% [markdown]
# '미술' 라벨에 대한 예측

# %%
predict_label("나는 동물을 크레파스로 그리는게 신나", model)
# Out:
# '미술'

# %% [markdown]
# '관계' 라벨에 대한 예측

# %%
predict_label("나는 친구를 도와줘서 칭찬을 받는게 좋아", model)
# Out:
# '관계'

# %% [markdown]
# '수리'라벨에 대한 예측

# %%
predict_label("나는 숫자를 공부해서 나중에 프로그래머가 되고 싶어요", model)
# Out:
# '수리'
